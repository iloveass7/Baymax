# %% [markdown]
# <a href="https://colab.research.google.com/github/iloveass7/Baymax/blob/main/wackyass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from keras import metrics

# %%
(x_train,y_train),(x_test,y_test) = keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.matshow(x_test[0])

# %%
y_test[0]
# Out:
# np.uint8(7)

# %%
x_train = x_train/255
x_test = x_test/255

# %%
x_train_flat = x_train.reshape(len(x_train),28*28)
x_train_flat.shape
# Out:
# (60000, 784)

# %%
x_test_flat = x_test.reshape(len(x_test),28*28)
x_test_flat.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
    keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(x_train_flat,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8098 - loss: 0.7343
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9133 - loss: 0.3108
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9199 - loss: 0.2850
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9219 - loss: 0.2797
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9254 - loss: 0.2664

# %%
model.evaluate(x_test_flat,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9135 - loss: 0.3060
# [0.2686823606491089, 0.925000011920929]

# %%
plt.matshow(x_test[0])

# %%
y_predicted = model.predict(x_test_flat)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_predicted[0]
# Out:
# array([1.4561873e-02, 3.4225849e-07, 7.0917413e-02, 9.5884657e-01,
#        2.3329188e-03, 1.1876260e-01, 9.7248289e-07, 9.9982613e-01,
#        7.5526126e-02, 6.4550567e-01], dtype=float32)

# %%
np.argmax(y_predicted[0])
# Out:
# np.int64(7)

# %%
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 955,    0,    2,    2,    0,    5,   10,    3,    2,    1],
#        [   0, 1119,    2,    2,    0,    1,    4,    2,    5,    0],
#        [   3,   13,  914,   18,    9,    5,   12,   13,   40,    5],
#        [   1,    0,   17,  936,    0,   20,    2,   11,   15,    8],
#        [   1,    1,    2,    2,  911,    0,   12,    5,    9,   39],
#        [   7,    3,    2,   38,    9,  785,   13,    7,   22,    6],
#        [   7,    3,    5,    1,    7,   16,  915,    2,    2,    0],
#        [   1,    6,   21,    4,    4,    0,    0,  963,    1,   28],
#        [   4,   12,    5,   31,    9,   41,    9,   14,  840,    9],
#        [  10,    7,    1,   12,   25,    9,    0,   30,    3,  912]],
#       dtype=int32)>

# %%
model = keras.Sequential([
    keras.layers.Dense(100,input_shape=(784,),activation='relu'),
    keras.layers.Dense(50,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.fit(x_train_flat,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8683 - loss: 0.4422
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9639 - loss: 0.1174
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9757 - loss: 0.0767
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9821 - loss: 0.0570
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9874 - loss: 0.0417
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9882 - loss: 0.0354
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9898 - loss: 0.0291
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9903 - loss: 0.0248
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9898 - loss: 0.0228
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9924 - loss: 0.0186

# %%
model.evaluate(x_test_flat,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9716 - loss: 0.1081
# [0.08848923444747925, 0.9747999906539917]
